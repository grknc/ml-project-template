# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
#
# Use this notebook to understand the dataset before modeling.

# %% [markdown]
# ## Objectives
# - Load a raw dataset from `data/raw/`
# - Inspect schema, null values, and class distribution
# - Produce basic visualizations and observations
#
# > **Learner task:** Replace placeholder file names and target column names.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
# Load data
# TODO: Update file name for your dataset
DATA_PATH = "data/raw/sample.csv"
df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
df.head()

# %%
# Basic quality checks
print(df.info())
print(df.isnull().sum().sort_values(ascending=False).head(10))
print(df.describe(include="all").T.head(10))

# %%
# Basic cleaning example
# - remove duplicates
# - standardize column names
df = df.drop_duplicates()
df.columns = [c.strip().lower() for c in df.columns]

# TODO: customize missing-value strategy for your case
for col in df.select_dtypes(include=["number"]).columns:
    df[col] = df[col].fillna(df[col].median())
for col in df.select_dtypes(exclude=["number"]).columns:
    df[col] = df[col].fillna("unknown")

df.head()

# %%
# Target distribution (classification)
# TODO: set your target column
target_col = "target"
if target_col in df.columns:
    sns.countplot(x=df[target_col])
    plt.title("Target distribution")
    plt.xticks(rotation=30)
    plt.show()
else:
    print(f"Column '{target_col}' not found. Update target_col first.")

# %% [markdown]
# ## EDA Notes
# - Key data quality issues:
# - Candidate features:
# - Potential leakage risks:
# - Hypotheses for modeling:
